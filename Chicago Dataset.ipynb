# %% [markdown]
# # Project Brief
# Crime in Chicago has been worrisomr to the chicago PD. Reported Crimes have been tracked on a daily basis since 2001 and have been provided in the project data file. The Chicago PD would like to drastically reduce the spate of violent crimes reported in the city. Being effective involves knowing crime pattern and where they are likely to occur. It also involves equipping the Police Department appropriately. They have recruited you to conduct full data analytics and uncover insights from the data that can be used to effectively prepere for and respond to crimes.
#
# They are interested in gleaning any insight that can help them determine
# - What type of Crime to Prepare for?
# - Where these Crimes are mostly to occur?
# - What days of the week and periods to expect these crimes?

# %% [markdown]
# ## Proposal:
# 1. Introduction of Dataset
# 2. Exploratory Data Analysis (EDA)
# 3. Dash Board
# 4. Conclusion and Summary
#
#
# - Exploratory Data Analysis (EDA) is about getting an overall understanding of data. EDA includes exploring data to find its main characteristics, identifying patterns and visualizations. EDA provides meaningful insights into data to be used in a variety of applications e.g,. machine learning. Python can be effectively used to do EDA as it has a rich set of easy-to-use libraries like Pandas, Seaborn, Numpy and Matplotlib.
# - In this project I will cover basics of EDA using a chicago data set, including, but not limited to, Correlating, Converting, Completing, Correcting, Creating and Charting the data.

# %% [markdown]
# # A brief introduction of installed libraries:
# I will be using installed libraries to perform different operations on data. Let’s explore these libraries a bit.
# __● Numpy__: NumPy is a library for the Python programming language, addingsupport for large, multi-dimensional arrays and matrices, along with large collection of high-level mathematical functions to operate on these arrays.
# ○ http://www.numpy.org/
#
# __● Pandas:__ pandas is a python package providing fast, flexible, and expressivedata structures designed to make working with “relational” or “labeled”data both easy and intuitive. It aims to be the fundamental high-level building block for doing practical, real world data analysis in Python.Additionally, it has the broader goal of becoming the most powerful and
# flexible open source data analysis / manipulation tool available in any language. It is already well on its way toward this goal.
# ○ https://pandas.pydata.org/
#
# __● Seaborn:__ Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
# ○ https://seaborn.pydata.org/
#
# __● Matplotlib:__ Matplotlib is a Python 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms. ○ https://matplotlib.org/

# %% [markdown]
# ### Introduction of data:
# I will be using data of Chicago crime dataset. This data holds 20 years of crime history including crime type and information about the crime where it happened. The file crime.c
# sv contains 2278726 rows and 23 columns; Each row
# corresponds to an individual crime that happened in the city of chicago.
#
# Columns are the following:
#
#
# - unique_key: Unique identifier for the record.
#
# - case_number The Chicago Police Department RD Number (Records Division Number), which is unique to the incident.
#
# - date: Date when the incident occurred. this is sometimes a best estimate.
#
# - block:The partially redacted address where the incident occurred, placing it on the same block as the actual address.
#
# - iucr:The Illinois Unifrom Crime Reporting code. This is directly linked to the Primary Type and Description. See the list of IUCR codes at https://data.cityofchicago.org/d/c7ck-438e.
#
# - primary_type:The primary description of the IUCR code.
#
# - description:The secondary description of the IUCR code, a subcategory of the primary description.
#
# - location_description :Description of the location where the incident occurred.
#
# - arrest: Indicates whether an arrest was made.
#
# - domestic:Indicates whether the incident was domestic-related as defined by the Illinois Domestic Violence Act.
#
# - beat: Indicates the beat where the incident occurred. A beat is the smallest police geographic area – each beat has a dedicated police beat car. Three to five beats make up a police sector, and three sectors make up a police district. The Chicago Police Department has 22 police districts. See the beats at https://data.cityofchicago.org/d/aerh-rz74.
#
# - district:Indicates the police district where the incident occurred. See the districts at https://data.cityofchicago.org/d/fthy-xz3r.
#
# - ward:The ward (City Council district) where the incident occurred. See the wards at https://data.cityofchicago.org/d/sp34-6z76.
#
# - community_area: Indicates the community area where the incident occurred. Chicago has 77 community areas. See the community areas at https://data.cityofchicago.org/d/cauq-8yn6.
#
# - fbi_code: Indicates the crime classification as outlined in the FBI's National Incident-Based Reporting System (NIBRS). See the Chicago Police Department listing of these classifications at http://gis.chicagopolice.org/clearmap_crime_sums/crime_types.html.
#
# - x_coordinate: The x coordinate of the location where the incident occurred in State Plane Illinois East NAD 1983 projection. This location is shifted from the actual location for partial redaction but falls on the same block.
#
# - y_coordinate:The y coordinate of the location where the incident occurred in State Plane Illinois East NAD 1983 projection. This location is shifted from the actual location for partial redaction but falls on the same block.
#
# - year :Year the incident occurred.
#
# - updated_on:Date and time the record was last updated.
#
# - latitude:The latitude of the location where the incident occurred. This location is shifted from the actual location for partial redaction but falls on the same block.
#
# - longitude:The longitude of the location where the incident occurred. This location is shifted from the actual location for partial redaction but falls on the same block.
#
# - location:The location where the incident occurred in a format that allows for creation of maps and other geographic

# %%
# import libaries
import pandas as pd
import numpy as np
from pandas import set_option
# for data visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Supress Warnings
import warnings
warnings.filterwarnings("ignore")
 #treatment of the outlier
from scipy import stats
import numpy as np

# %%
# To load the dataet
df=pd.read_csv("C:/Users/Dell/Documents/Deji Folder/Workplace/crime_data_Proj1/crime_data_Proj1.csv")

# %%
# To view the dataset
df.head()
# Out:
#    Unnamed: 0        ID Case Number                    Date  \
# 0           0   6407111    HP485721  07/26/2008 02:30:00 PM
# 1           1  11398199    JB372830  07/31/2018 10:57:00 AM
# 2           2   5488785    HN308568  04/27/2007 10:30:00 AM
# 3           3  11389116    JB361368  07/23/2018 08:55:00 AM
# 4           4  12420431    JE297624  07/11/2021 06:40:00 AM
#
#                   Block  IUCR       Primary Type               Description  \
# 0  085XX S MUSKEGON AVE  1320    CRIMINAL DAMAGE                TO VEHICLE
# 1     092XX S ELLIS AVE  143C  WEAPONS VIOLATION  UNLAWFUL POSS AMMUNITION
# 2     062XX N TRIPP AVE  0610           BURGLARY            FORCIBLE ENTRY
# 3    0000X N KEELER AVE  0560            ASSAULT                    SIMPLE
# 4   016XX W HARRISON ST  051A            ASSAULT      AGGRAVATED - HANDGUN
#
#                      Location Description  Arrest  ...  Ward  Community Area  \
# ...

# %%
print(max(df["Year"]),min(df["Year"]))
# Out:
# 2022 2001

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2278726 entries, 0 to 2278725
# Data columns (total 23 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Unnamed: 0            int64
#  1   ID                    int64
#  2   Case Number           object
#  3   Date                  object
#  4   Block                 object
#  5   IUCR                  object
#  6   Primary Type          object
#  7   Description           object
#  8   Location Description  object
#  9   Arrest                bool
#  10  Domestic              bool
#  11  Beat                  int64
#  12  District              float64
#  13  Ward                  float64
#  14  Community Area        float64
#  15  FBI Code              object
#  16  X Coordinate          float64
#  17  Y Coordinate          float64
#  18  Year                  int64
#  19  Updated On            object
#  20  Latitude              float64
#  21  Longitude             float64
# ...

# %% [markdown]
# ## Cleaning and Completing Data:
# At this point we are well aware of our data. I know that it has some missing values and some features are not important for this analysis.
#
# I will perform different operations on it. E.g
#
# ● Exclude all features from data where 1 don’t need for this analysis.E.g IUCR, FBI code etc
#
# ● I will form new Features like period, crime-hour etc
#
# ● Out of the Population of the Crime Dataset, i will be using 100,000 as sample of the dataset for analysis
#
# ● I will then drop sample where there is missing values.

# %%
dfsub=df.loc[:,['Date', 'Block','Primary Type', 'Description', 'Location Description', 'Arrest',
       'Domestic', 'District','Year', 'Updated On']]

# %%
dfsub=dfsub.dropna()

# %%
dfsub=dfsub[:100000]

# %%
dfsub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 100109
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Date                  100000 non-null  object
#  1   Block                 100000 non-null  object
#  2   Primary Type          100000 non-null  object
#  3   Description           100000 non-null  object
#  4   Location Description  100000 non-null  object
#  5   Arrest                100000 non-null  bool
#  6   Domestic              100000 non-null  bool
#  7   District              100000 non-null  float64
#  8   Year                  100000 non-null  int64
#  9   Updated On            100000 non-null  object
# dtypes: bool(2), float64(1), int64(1), object(6)
# memory usage: 7.1+ MB

# %%
dfsub.isnull().sum()
# Out:
# Date                    0
# Block                   0
# Primary Type            0
# Description             0
# Location Description    0
# Arrest                  0
# Domestic                0
# District                0
# Year                    0
# Updated On              0
# dtype: int64

# %%
print("shape of heart dataset",dfsub.shape)
print(f" The number of sample present in the data is {dfsub.shape[0]} and the feature of the data is {dfsub.shape[1]}")
# Out:
# shape of heart dataset (100000, 10)
#  The number of sample present in the data is 100000 and the feature of the data is 10

# %%
from dateutil.parser import parse
from datetime import datetime


tCol = dfsub.Date

List = [(datetime.ctime(parse(x[0:-3])),x[-2:]) for x in tCol]
dayList = []
monthList = []
periodList = []
for row in List:
    day = row[0][0:4]
    month = row[0][4:7]
    if row[1]=='AM':
        period = 'Morning'
    elif row[1] =='PM' and int(row[0][11:13])<4:
        period = 'Afternoon'
    elif row[1] =='PM' and int(row[0][11:13])<6:
        period = 'Evening' 
    elif row[1] =='PM' and int(row[0][11:13])>5:
        period = 'Night'
    else:
        period = 'Unknown'
        
    dayList.append(day)
    monthList.append(month)
    periodList.append(period)
    
print(len(dayList), len(monthList), len(periodList))    

dfsub['month'] = monthList
dfsub['day'] = dayList
#dfsub['period']= periodList


weeklist=[]
for day in list(dfsub.day):
    if day in ["Sat ","Sun "]:
        weeklist.append("Weekend")
    else:
        weeklist.append("Week-Day")
        
        
dfsub["Day-Type"]=weeklist

dfsub["Date"]=pd.to_datetime(dfsub["Date"])
dfsub["Updated On"]=pd.to_datetime(dfsub["Updated On"])

dfsub["Day Difference"]=dfsub["Updated On"]-dfsub["Date"]

dfsub["Crime_Hour"]=dfsub["Date"].dt.hour
# new Column Days Of the Month
dfsub["D_O_M"]=dfsub["Date"].dt.day
# Out:
# 100000 100000 100000

# %%
dfsub.head()
# Out:
#                  Date                 Block       Primary Type  \
# 0 2008-07-26 14:30:00  085XX S MUSKEGON AVE    CRIMINAL DAMAGE
# 1 2018-07-31 10:57:00     092XX S ELLIS AVE  WEAPONS VIOLATION
# 2 2007-04-27 10:30:00     062XX N TRIPP AVE           BURGLARY
# 3 2018-07-23 08:55:00    0000X N KEELER AVE            ASSAULT
# 4 2021-07-11 06:40:00   016XX W HARRISON ST            ASSAULT
#
#                 Description                    Location Description  Arrest  \
# 0                TO VEHICLE                                  STREET   False
# 1  UNLAWFUL POSS AMMUNITION                               POOL ROOM    True
# 2            FORCIBLE ENTRY                               RESIDENCE    True
# 3                    SIMPLE            NURSING HOME/RETIREMENT HOME   False
# 4      AGGRAVATED - HANDGUN  PARKING LOT / GARAGE (NON RESIDENTIAL)   False
#
#    Domestic  District  Year          Updated On month   day  Day-Type  \
# ...

# %%
dfFinal=dfsub[['Block', 'Primary Type', 'Description', 'Location Description',
       'Arrest', 'Domestic', 'District', 'Year', 'month', 'day',
       'Day-Type','Crime_Hour', 'Day Difference',"D_O_M"]]

# %% [markdown]
# ## Periods/Time
# __The Period is divided into with 3hours or more interval.__
#  - Early Morning (4am-8am inclusive)
#  - Late Morning ( 9am-11am inclusive)
#  - Mid-day&Early Afternoon (12pm-2pm inclusive)
#  - Late Afternoon(3pm-4pm inclusive)
#  - Evening (5pm-7pm inclusive)
#  - Early Night(8pm-11pm inclusive)
#  - late Night(12pm-3am inclusive)

# %%
perlist=[]
for hour in list(dfFinal.Crime_Hour):
    if hour in [4,5,6,7,8]:
        perlist.append("Early Morning")
    elif hour in [9,10,11]:
        perlist.append("Late Morning")
    elif hour in [12,13,14]:
        perlist.append("Mid-day/Early_Afternoon")
    elif hour in [15,16,]:
        perlist.append("late_Afternoon")
    elif hour in [17,18,19,]:
        perlist.append("Evening")
    elif hour in [20,21,22,23]:
        perlist.append("Early_Night")
        
    else:
        perlist.append("Late-Night")
        
        
dfFinal["Period_time"]=perlist

# %%
def get_place(place):
    return place.split(" ")[-1]

def get_region(region):
    return region.split(" ")[1]


dfFinal["Block_place"]=dfFinal["Block"].apply(lambda x:get_place(x))

dfFinal["Block_region"]=dfFinal["Block"].apply(lambda x:get_region(x))

# %%
dfFinal.columns=dfFinal.columns.str.replace(' ','_')

# %%
dfFinal.describe(include="all").T
# Out:
#                          count unique               top   freq  \
# Block                   100000  26822  100XX W OHARE ST    210
# Primary_Type            100000     34             THEFT  21345
# Description             100000    389            SIMPLE  11828
# Location_Description    100000    146            STREET  25934
# Arrest                  100000      2             False  73511
# Domestic                100000      2             False  86214
# District              100000.0    NaN               NaN    NaN
# Year                  100000.0    NaN               NaN    NaN
# month                   100000     12               Jul   9282
# day                     100000      7              Fri   15193
# Day-Type                100000      2          Week-Day  72125
# Crime_Hour            100000.0    NaN               NaN    NaN
# Day_Difference          100000    NaN               NaN    NaN
# D_O_M                 100000.0    NaN               NaN    NaN
# ...

# %%
set(perlist)
# Out:
# {'Early Morning',
#  'Early_Night',
#  'Evening',
#  'Late Morning',
#  'Late-Night',
#  'Mid-day/Early_Afternoon',
#  'late_Afternoon'}

# %%
# Categorical variables in our data:abs

catFeature = [col for col in dfFinal.columns if pd.api.types.is_string_dtype(dfFinal[col])] # list comprehension
print(catFeature)
labelDict = {}
for col in catFeature:
    labels = dfFinal[col].unique()
    labelDict[col] = labels
# Out:
# ['Block', 'Primary_Type', 'Description', 'Location_Description', 'month', 'day', 'Day-Type', 'Period_time', 'Block_place', 'Block_region']

# %% [markdown]
# # Primary Crime Type

# %%
len(df["Primary Type"].unique())
# Out:
# 35

# %%
labelDict["Primary_Type"]
# Out:
# array(['CRIMINAL DAMAGE', 'WEAPONS VIOLATION', 'BURGLARY', 'ASSAULT',
#        'THEFT', 'ROBBERY', 'NARCOTICS', 'MOTOR VEHICLE THEFT', 'BATTERY',
#        'OTHER OFFENSE', 'PROSTITUTION', 'DECEPTIVE PRACTICE',
#        'INTIMIDATION', 'INTERFERENCE WITH PUBLIC OFFICER',
#        'CRIMINAL TRESPASS', 'STALKING', 'OFFENSE INVOLVING CHILDREN',
#        'PUBLIC PEACE VIOLATION', 'SEX OFFENSE', 'CRIM SEXUAL ASSAULT',
#        'HOMICIDE', 'LIQUOR LAW VIOLATION', 'CRIMINAL SEXUAL ASSAULT',
#        'KIDNAPPING', 'ARSON', 'GAMBLING',
#        'CONCEALED CARRY LICENSE VIOLATION', 'PUBLIC INDECENCY',
#        'RITUALISM', 'OBSCENITY', 'NON - CRIMINAL',
#        'OTHER NARCOTIC VIOLATION', 'HUMAN TRAFFICKING', 'NON-CRIMINAL'],
#       dtype=object)

# %%
labelDict["Block_place"]
# Out:
# array(['AVE', 'ST', 'PL', 'BLVD', 'RD', 'H', 'AV', 'DR', 'N', 'BROADWAY',
#        'PKWY', 'Ave', 'W', 'C', 'PW', 'CT', 'TER', 'SB', 'OVERPASS', 'L',
#        'HWY', 'BL', 'E', 'M', 'St', 'DEARBORN', 'J', 'G', 'LN', 'PLZ',
#        'O', 'PARK', 'D', 'SD', 'MARKET', 'XP', 'F', 'BV', 'S', 'RIVER',
#        'OB', 'TR', 'LSD', 'K', 'ave', 'CHICAGO', 'PZ', 'WEST', 'PEORIA',
#        'GROVE', 'NB', 'IB', 'PLAISANCE', 'B', 'SQ', 'ST.', '27R', 'FIELD',
#        'Pl', 'Blvd', 'I55', 'VLISSINGEN', 'st', 'Rd', 'rd', 'WAY', 'XR',
#        'STREET', 'TRL', 'RAMP'], dtype=object)

# %%
len(labelDict["Primary_Type"])
# Out:
# 34

# %% [markdown]
# __There are 35 different crime reported to the Chicago PD__
# In the sample of data,There is 34 crime fully
# - In this analysis, basically Top 10 crime will be fully

# %%
df_Prim=dfFinal.groupby(by="Primary_Type")["District"].count().sort_values(ascending=False).reset_index(name="counts")
df_Prim.head(10)
# Out:
#           Primary_Type  counts
# 0                THEFT   21345
# 1              BATTERY   18413
# 2      CRIMINAL DAMAGE   11448
# 3            NARCOTICS    9748
# 4              ASSAULT    6502
# 5        OTHER OFFENSE    6059
# 6             BURGLARY    5402
# 7  MOTOR VEHICLE THEFT    4632
# 8   DECEPTIVE PRACTICE    4188
# 9              ROBBERY    3822

# %%
plt.figure(figsize=(20,10))
sns.countplot(dfFinal["Primary_Type"])
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(15,8))
crime_count=dfFinal["Primary_Type"].value_counts()
ax=crime_count[:10].plot.bar(color="darkred")

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
plt.xlabel("Primary Crime Type",size=25)
plt.ylabel("COUNT ",size=25)
plt.xticks(rotation=90,size=15)
plt.title("Top 10 crime that happened  in the city of Chicage",size=30)
plt.show()

# %% [markdown]
# ##   THEFT

# %%
THEFT=dfFinal[dfFinal["Primary_Type"]=="THEFT"]
THEFT.head()
# Out:
#                    Block Primary_Type     Description  \
# 5          003XX W 28 PL        THEFT       OVER $500
# 17      009XX W GRACE ST        THEFT  $500 AND UNDER
# 23  003XX S MICHIGAN AVE        THEFT  $500 AND UNDER
# 28  008XX N MICHIGAN AVE        THEFT  POCKET-PICKING
# 34   005XX W DIVISION ST        THEFT   FROM BUILDING
#
#             Location_Description  Arrest  Domestic  District  Year month  \
# 5                         STREET   False     False       2.0  2001   Aug
# 17                         OTHER   False     False      19.0  2004   Jul
# 23                 PARK PROPERTY   False     False       1.0  2008   Oct
# 28  GOVERNMENT BUILDING/PROPERTY   False     False      18.0  2013   Oct
# 34                     APARTMENT   False     False      18.0  2020   Dec
#
#      day  Day-Type  Crime_Hour     Day_Difference  D_O_M  \
# 5   Tue   Week-Day           0 5109 days 15:03:40     21
# 17  Fri   Week-Day           0 4968 days 15:56:25     23
# ...

# %%
plt.figure(figsize=(15,8))
THEFT_count=THEFT["Location_Description"].value_counts()
ax=THEFT_count[:10].plot.bar(color="darkred")

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
plt.xlabel("LOCATION DESCRIPTION",size=20)
plt.ylabel("COUNT ",size=20)
plt.xticks(rotation=90,size=15)
plt.title("Top 10 location that Theft occurs in the city of chicago",size=25)
plt.show()

# %%
plt.figure(figsize=(15,8))
THEFT_count=THEFT["Description"].value_counts()
ax=THEFT_count[:10].plot.bar(color="darkblue")

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
plt.xlabel("Description Of Theft that Happened",size=20)
plt.ylabel("COUNT ",size=20)
plt.xticks(rotation=90,size=15)
plt.title("Top 10 Description of What happend during Theft in the city of chicago",size=25)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax=sns.countplot(THEFT["Period_time"])
plt.xticks(rotation=45,size=15)
plt.xlabel("Period Of Time",size=25)
plt.title("Chart Showing the Period that Theft Happened",size=20)
plt.ylabel("Counts",size=20)
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.35, p.get_height()), ha='center', va='top', color='white', size=18)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax=sns.countplot(THEFT["day"])
plt.yticks(size=15)
plt.xticks(rotation=45,size=15)
plt.xlabel("DAY",size=20)
plt.ylabel("COUNT",size=25)

plt.title("Chart Showing Countplot of the Day that Theft Happened",size=25)
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.35, p.get_height()), ha='center', va='top', color='white', size=18)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax=sns.countplot(THEFT['Crime_Hour'])
plt.xticks(rotation=45,size=15)
plt.title("Chart Showing countplot the hour that each Theft crime happened ",size=25)
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.35, p.get_height()), ha='center', va='top', color='black', size=18)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.histplot(THEFT['D_O_M'],bins=5)
plt.title("Disturbtion showing crime in Days accross the each Month",size=30)
plt.xticks(rotation=45,size=30)
plt.xlabel("Days of the Month",size=30)
plt.ylabel("Counts",size=30)
plt.yticks(size=30)
plt.show()

# %% [markdown]
# # INSIGHT
# - Most Theft happened on the streets,resdience place like apartment etc and stores.
# - Most Theft are issue of monetary things.
# - Most Theft happened during the mid-day/Early Afternoon(12pm-3pm), Evening(5pm-7pm) and Early-Night(8pm-11pm)
# - At or Around 12 pm mid-day, there is a lot of theft
# - The rate of theft increase as the end of month.

# %% [markdown]
# ##  Battery

# %%
Battery=dfFinal[dfFinal["Primary_Type"]=="BATTERY"]
Battery.head()
# Out:
#                        Block Primary_Type              Description  \
# 11        058XX S KEDZIE AVE      BATTERY  DOMESTIC BATTERY SIMPLE
# 16         047XX W FULTON ST      BATTERY  DOMESTIC BATTERY SIMPLE
# 19          023XX S STATE ST      BATTERY                   SIMPLE
# 21       133XX S BRANDON AVE      BATTERY                   SIMPLE
# 32  053XX W BLOOMINGDALE AVE      BATTERY  DOMESTIC BATTERY SIMPLE
#
#    Location_Description  Arrest  Domestic  District  Year month   day  \
# 11            APARTMENT   False      True       8.0  2008   Oct  Sun
# 16            APARTMENT   False      True      11.0  2015   Jun  Sun
# 19        CHA APARTMENT   False      True       1.0  2002   Jan  Wed
# 21               STREET   False     False       4.0  2002   Oct  Sat
# 32            RESIDENCE   False      True      25.0  2020   Apr  Sun
#
#     Day-Type  Crime_Hour     Day_Difference  D_O_M              Period_time  \
# ...

# %%
plt.figure(figsize=(15,8))
Battery_count=Battery["Location_Description"].value_counts()
ax=Battery_count[:10].plot.bar(color="darkred")

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
plt.xlabel("LOCATION DESCRIPTION",size=20)
plt.ylabel("COUNT ",size=20)
plt.xticks(rotation=45,size=15)
plt.title("Top 10 location that Battery occurs in the city of chicago",size=25)
plt.show()

# %%
plt.figure(figsize=(15,8))
Battery_count=Battery["Description"].value_counts()
ax=Battery_count[:10].plot.bar(color="darkblue")

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
plt.xlabel("Description Of battery Happened",size=20)
plt.ylabel("COUNT ",size=20)
plt.xticks(rotation=90,size=15)
plt.title("Top 10 Description of What happend during Battery in the city of chicago",size=25)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax=sns.countplot(Battery["Period_time"])
plt.xticks(rotation=45,size=15)
plt.xlabel("Period Of Time",size=25)
plt.title("Chart Showing the Period that Battery Happened",size=20)
plt.ylabel("Counts",size=20)
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.35, p.get_height()), ha='center', va='top', color='white', size=18)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax=sns.countplot(Battery["Block_region"])
plt.xticks(rotation=45,size=15)
plt.xlabel("Region if the Crime ",size=25)
plt.title("Chart Showing Countplot of the BlocK-Region that Battery Happened",size=20)
plt.ylabel("Counts",size=20)
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.35, p.get_height()), ha='center', va='top', color='white', size=18)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax=sns.countplot(Battery['Crime_Hour'])
plt.xticks(rotation=45,size=15)
plt.title("Chart Showing countplot the hour that each Battery crime happened ",size=25)
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.35, p.get_height()), ha='center', va='top', color='black', size=18)
plt.show()

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(Battery["Domestic"])
plt.xticks(rotation=45)
plt.title("")
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.35, p.get_height()), ha='center', va='top', color='white', size=18)
plt.show()

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(Battery["Arrest"])
plt.xticks(rotation=45)
plt.title("")
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.35, p.get_height()), ha='center', va='top', color='white', size=18)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.histplot(Battery['D_O_M'],bins=10)
plt.title("Disturbtion showing  battery crime in Days accross the each Month",size=30)
plt.xticks(rotation=45,size=30)
plt.xlabel("Days of the Month",size=30)
plt.ylabel("Counts",size=30)
plt.yticks(size=30)
plt.show()

# %% [markdown]
# # INSIGHT FOR BATTERY
#
# - Most battery happened on the streets,resdience place like apartment etc and public places.
# - Most Battery reported are simple like beating up.
# - Most Battery happened during the Night and evening.
# - South region of the city has most battery.
# - The rate of theft increase as the end of month.

# %% [markdown]
# # NARCOTICS

# %%
NARCOTICS=dfFinal.query("Primary_Type =='NARCOTICS'")
NARCOTICS.head()
# Out:
#                      Block Primary_Type                   Description  \
# 7      043XX W POTOMAC AVE    NARCOTICS  POSS: CANNABIS 30GMS OR LESS
# 9   021XX N CALIFORNIA AVE    NARCOTICS  POSS: CANNABIS 30GMS OR LESS
# 10     031XX W WARREN BLVD    NARCOTICS  MANU/DELIVER: HEROIN (WHITE)
# 18       002XX N LOREL AVE    NARCOTICS                   POSS: CRACK
# 36      031XX S HALSTED ST    NARCOTICS                   POSS: CRACK
#
#                Location_Description  Arrest  Domestic  District  Year month  \
# 7                             ALLEY    True     False      25.0  2014   Dec
# 9   POLICE FACILITY/VEH PARKING LOT    True     False      14.0  2016   Jun
# 10                         SIDEWALK    True     False      12.0  2014   Jan
# 18                         SIDEWALK    True     False      15.0  2003   Apr
# 36  POLICE FACILITY/VEH PARKING LOT    True     False       9.0  2015   Dec
#
#      day  Day-Type  Crime_Hour     Day_Difference  D_O_M     Period_time  \
# ...

# %%
plt.figure(figsize=(15,8))
NARCOTICS_count=NARCOTICS["Location_Description"].value_counts()
ax=NARCOTICS_count[:10].plot.bar(color="darkred")

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
plt.xlabel("LOCATION DESCRIPTION",size=20)
plt.ylabel("COUNT ",size=20)
plt.xticks(rotation=90,size=15)
plt.title("Top 10 location that NARCOTICS occurs in the city of chicago",size=25)
plt.show()

# %%
plt.figure(figsize=(15,8))
NARCOTICS_count=NARCOTICS["Description"].value_counts()
ax=NARCOTICS_count[:10].plot.bar(color="darkblue")

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
plt.xlabel("Description Of Narcotics Happened",size=20)
plt.ylabel("COUNT ",size=20)
plt.xticks(rotation=90,size=15)
plt.title("Top 10 Description of What happend during Narcotics in the city of chicago",size=25)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax=sns.countplot(NARCOTICS["Period_time"])
plt.xticks(rotation=45,size=15)
plt.xlabel("Period Of Time",size=25)
plt.title("Chart Showing the Period that NARCOTICS Happened",size=20)
plt.ylabel("Counts",size=20)
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.35, p.get_height()), ha='center', va='top', color='white', size=18)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax=sns.countplot(NARCOTICS["day"])
plt.yticks(size=15)
plt.xticks(rotation=45,size=15)
plt.xlabel("DAY",size=20)
plt.ylabel("COUNT",size=25)

plt.title("Chart Showing Countplot of the Day that NARCOTICS  Happened",size=25)
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.35, p.get_height()), ha='center', va='top', color='white', size=18)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax=sns.countplot(NARCOTICS["month"])
plt.yticks(size=15)
plt.xticks(rotation=45,size=15)
plt.xlabel("DAY",size=20)
plt.ylabel("COUNT",size=25)

plt.title("Chart Showing Countplot of the Day that NARCOTICS Happened",size=25)
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.35, p.get_height()), ha='center', va='top', color='white', size=18)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax=sns.countplot(NARCOTICS["Block_region"])
plt.xticks(rotation=45,size=15)
plt.xlabel("Region if the Crime ",size=25)
plt.title("Chart Showing Countplot of the BlocK-Region that NARCOTICS Happened",size=20)
plt.ylabel("Counts",size=20)
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.35, p.get_height()), ha='center', va='top', color='white', size=18)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.histplot(NARCOTICS['D_O_M'],bins=10)
plt.title("Disturbtion showing  NARCOTICS crime in Days accross the each Month",size=30)
plt.xticks(rotation=45,size=30)
plt.xlabel("Days of the Month",size=30)
plt.ylabel("Counts",size=30)
plt.yticks(size=30)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax=sns.countplot(NARCOTICS['Crime_Hour'])
plt.xticks(rotation=45,size=15)
plt.title("Chart Showing countplot the hour that each NARCOTICS crime happened ",size=25)
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.35, p.get_height()), ha='center', va='top', color='black', size=18)
plt.show()

# %%
plt.figure(figsize=(22,10))
ax=sns.countplot(NARCOTICS["day"],hue=NARCOTICS["Period_time"])
plt.xticks(rotation=45)
plt.title("")
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.35, p.get_height()), ha='center', va='top', color='white', size=18)
plt.show()

# %%
# same pattern it folo

# %% [markdown]
# # INSIGHT FOR NARCOTICS
#
# - Most Narcotics happened on the streets and side walk  especialy early at Night around 7pm to 11pm.
# - It is mostly rampant in the region (West and North) of the City.
# - Most Narcotics are hard drug like cannabils,cracks and heroin
# - There is no period/season they don't take drug.
# - The rate of theft increase as the end of month.

# %% [markdown]
# ## ROBBERY

# %%
ROBBERY=dfFinal.query("Primary_Type =='ROBBERY'")
ROBBERY.head()
# Out:
#                     Block Primary_Type            Description  \
# 6     006XX S CENTRAL AVE      ROBBERY  STRONGARM - NO WEAPON
# 43     016XX W ADDISON ST      ROBBERY  STRONGARM - NO WEAPON
# 57  067XX S CHAMPLAIN AVE      ROBBERY  STRONGARM - NO WEAPON
# 67       051XX W BARRY AV      ROBBERY         ARMED: HANDGUN
# 79      076XX S ESSEX AVE      ROBBERY         ARMED: HANDGUN
#
#    Location_Description  Arrest  Domestic  District  Year month   day  \
# 6          CTA PLATFORM   False     False      15.0  2006   Oct  Sat
# 43               STREET   False     False      19.0  2002   Aug  Sat
# 57             SIDEWALK   False     False       3.0  2003   May  Thu
# 67               STREET   False     False      25.0  2002   Apr  Fri
# 79               STREET   False     False       4.0  2017   Mar  Mon
#
#     Day-Type  Crime_Hour     Day_Difference  D_O_M              Period_time  \
# 6    Weekend          22 4154 days 17:56:25     14              Early_Night
# ...

# %%
plt.figure(figsize=(15,8))
ROBBERY_count=ROBBERY["Location_Description"].value_counts()
ax=ROBBERY_count[:10].plot.bar(color="darkred")

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
plt.xlabel("LOCATION DESCRIPTION",size=20)
plt.ylabel("COUNT ",size=20)
plt.xticks(rotation=90,size=15)
plt.title("Top 10 location that Robbery occurs in the city of chicago",size=25)
plt.show()

# %%
plt.figure(figsize=(15,8))
ROBBERY_count=ROBBERY["Description"].value_counts()
ax=ROBBERY_count[:10].plot.bar(color="darkblue")

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
plt.xlabel("Description Of ROBBERY Incident",size=20)
plt.ylabel("COUNT ",size=20)
plt.xticks(rotation=90,size=15)
plt.title("Top 10 Description of What happend during ROBBERY in the city of chicago",size=25)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax=sns.countplot(ROBBERY["Period_time"])
plt.xticks(rotation=45,size=15)
plt.xlabel("Period Of Time",size=25)
plt.title("Chart Showing the Period that Robbery Happened",size=20)
plt.ylabel("Counts",size=20)
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.35, p.get_height()), ha='center', va='top', color='white', size=18)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax=sns.countplot(ROBBERY['Crime_Hour'])
plt.xticks(rotation=45,size=15)
plt.title("Chart Showing countplot the hour that each Robbery crime happened ",size=25)
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.35, p.get_height()), ha='center', va='top', color='black', size=18)
plt.show()

# %% [markdown]
# # INSIGIT FOR ROBBERY
# - Most Robbery happen on the street,sidewalk and public space like CTA Train , Gas Station.
# - Most Robbery are without weapon like strongman.
# - it occur mostly early Night and Evening.

# %% [markdown]
# # 'CRIMINAL DAMAGE'

# %%
CRIMINAL_DAMAGE=dfFinal.query("Primary_Type =='CRIMINAL DAMAGE'")
CRIMINAL_DAMAGE.head()
# Out:
#                    Block     Primary_Type  Description  \
# 0   085XX S MUSKEGON AVE  CRIMINAL DAMAGE   TO VEHICLE
# 20   022XX N NATCHEZ AVE  CRIMINAL DAMAGE   TO VEHICLE
# 33   011XX S WESTERN AVE  CRIMINAL DAMAGE  TO PROPERTY
# 44       003XX E 55TH PL  CRIMINAL DAMAGE  TO PROPERTY
# 50   030XX W HARRISON ST  CRIMINAL DAMAGE   TO VEHICLE
#
#             Location_Description  Arrest  Domestic  District  Year month  \
# 0                         STREET   False     False       4.0  2008   Jul
# 20            VEHICLE-COMMERCIAL   False     False      25.0  2010   Jan
# 33  COMMERCIAL / BUSINESS OFFICE   False     False      12.0  2022   Jan
# 44                     RESIDENCE   False     False       2.0  2005   Jul
# 50                        STREET   False     False      11.0  2017   May
#
#      day  Day-Type  Crime_Hour     Day_Difference  D_O_M  \
# 0   Sat    Weekend          14 3504 days 01:26:25     26
# 20  Thu   Week-Day           1 2949 days 14:50:01     14
# ...

# %%
plt.figure(figsize=(15,8))
CRIMINAL_DAMAGE_count=CRIMINAL_DAMAGE["Location_Description"].value_counts()
ax=CRIMINAL_DAMAGE_count[:10].plot.bar(color="darkred")

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
plt.xlabel("Location_Description" ,size=14)
plt.ylabel("COUNT ")
plt.xticks(rotation=270,size=15)
plt.title("Top 10 location that CRIMINAL_DAMAGE do happened in the city of chicago",size=25)
plt.show()

# %%
plt.figure(figsize=(15,8))
CRIMINAL_DAMAGE_count=CRIMINAL_DAMAGE["Description"].value_counts()
ax=CRIMINAL_DAMAGE_count[:10].plot.bar(color="darkblue")

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
plt.xlabel("Location_Description" ,size=14)
plt.ylabel("COUNT ")
plt.xticks(rotation=90)
plt.title("Top 10 location that CRIMINAL_DAMAGE do happened in the city of chicago",size=25)
plt.show()

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(CRIMINAL_DAMAGE["Period_time"])
plt.xticks(rotation=45)
plt.title("")
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.35, p.get_height()), ha='center', va='top', color='white', size=18)
plt.show()

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(CRIMINAL_DAMAGE["Block_region"])
plt.xticks(rotation=45)
plt.title("Region where CRIMINAL_DAMAGE happened in the city of chicago ",size=20)
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.35, p.get_height()), ha='center', va='top', color='white', size=18)
plt.show()

# %% [markdown]
# # INSIGHTS FOR CRIMINAL DAMAGE
# - Most criminal_damage happen on the street,residence area and apartment.
# - Criminal_damage are most on vechicle and property.
# - It happens most at night and evening.
# - The region where criminal_damage happen most is south and west of the city chicago.

# %% [markdown]
# # 'MOTOR VEHICLE THEFT'

# %%
motor=dfFinal[dfFinal["Primary_Type"]=="MOTOR VEHICLE THEFT"]
motor.head()
# Out:
#                     Block         Primary_Type                 Description  \
# 8      032XX W PIERCE AVE  MOTOR VEHICLE THEFT                  AUTOMOBILE
# 22  036XX S LAKE PARK AVE  MOTOR VEHICLE THEFT  THEFT/RECOVERY: AUTOMOBILE
# 25   078XX S PHILLIPS AVE  MOTOR VEHICLE THEFT                  AUTOMOBILE
# 39      048XX N AVERS AVE  MOTOR VEHICLE THEFT                  AUTOMOBILE
# 86      094XX S PERRY AVE  MOTOR VEHICLE THEFT                  AUTOMOBILE
#
#    Location_Description  Arrest  Domestic  District  Year month   day  \
# 8                STREET   False     False      14.0  2010   Jun  Wed
# 22               STREET   False     False       2.0  2002   Jul  Mon
# 25               STREET   False     False       4.0  2004   Jun  Sun
# 39               STREET   False     False      17.0  2004   May  Tue
# 86               STREET   False     False       6.0  2008   Aug  Tue
#
#     Day-Type  Crime_Hour     Day_Difference  D_O_M     Period_time  \
# ...

# %%
plt.figure(figsize=(15,8))
motor_count=motor["Location_Description"].value_counts()
ax=motor_count[:10].plot.bar(color="darkred")

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
plt.xlabel("Location_Description" ,size=14)
plt.ylabel("COUNT ")
plt.xticks(rotation=90)
plt.title("Top 10 location that motor theft do happened in the city of chicago",size=25)
plt.show()

# %%
plt.figure(figsize=(15,8))
motor_count=motor["Description"].value_counts()
ax=motor_count[:10].plot.bar(color="darkblue")

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
plt.xlabel("Location_Description" ,size=14)
plt.ylabel("COUNT ")
plt.xticks(rotation=90)
plt.title("Top 10 location that  motor theft do happened in the city of chicago",size=25)
plt.show()

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(motor["Period_time"])
plt.xticks(rotation=45)
plt.title("")
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.35, p.get_height()), ha='center', va='top', color='white', size=18)
plt.show()

# %%
plt.figure(figsize=(20,15))
ax=sns.countplot(motor["Block_place"])
plt.xticks(rotation=45)
plt.title("")
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.35, p.get_height()), ha='center', va='top', color='white', size=18)
plt.show()

# %% [markdown]
# # Location Description

# %%
df_Location=dfFinal.groupby(by="Location_Description")["District"].count().sort_values(ascending=False).reset_index(name="counts")
df_Location.head(10)
# Out:
#              Location_Description  counts
# 0                          STREET   25934
# 1                       RESIDENCE   16783
# 2                       APARTMENT   11123
# 3                        SIDEWALK    9658
# 4                           OTHER    3642
# 5  PARKING LOT/GARAGE(NON.RESID.)    2631
# 6                           ALLEY    2217
# 7              SMALL RETAIL STORE    1927
# 8        SCHOOL, PUBLIC, BUILDING    1922
# 9                RESIDENCE-GARAGE    1776

# %%
plt.figure(figsize=(15,8))
crime_count=dfFinal["Location_Description"].value_counts()
ax=crime_count[:10].plot.bar(color="darkgreen")

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
plt.xlabel("Location_Description",size=25)
plt.ylabel("COUNT ",size=25)
plt.xticks(rotation=90,size=15)
plt.title("Top 10 location that crime happened  in the city of Chicage",size=30)
plt.show()

# %%
stret=dfFinal.query("Location_Description =='STREET'")
stret.head()
# Out:
#                    Block         Primary_Type            Description  \
# 0   085XX S MUSKEGON AVE      CRIMINAL DAMAGE             TO VEHICLE
# 5          003XX W 28 PL                THEFT              OVER $500
# 8     032XX W PIERCE AVE  MOTOR VEHICLE THEFT             AUTOMOBILE
# 14   042XX S INDIANA AVE         PROSTITUTION  SOLICIT ON PUBLIC WAY
# 21   133XX S BRANDON AVE              BATTERY                 SIMPLE
#
#    Location_Description  Arrest  Domestic  District  Year month   day  \
# 0                STREET   False     False       4.0  2008   Jul  Sat
# 5                STREET   False     False       2.0  2001   Aug  Tue
# 8                STREET   False     False      14.0  2010   Jun  Wed
# 14               STREET    True     False       2.0  2012   Jul  Tue
# 21               STREET   False     False       4.0  2002   Oct  Sat
#
#     Day-Type  Crime_Hour     Day_Difference  D_O_M              Period_time  \
# ...

# %%
plt.figure(figsize=(15,8))
stret_count=stret["Block_place"].value_counts()
ax=stret_count[:20].plot.bar(color="darkblue")

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
plt.xlabel("Location_Description" ,size=14)
plt.ylabel("COUNT ")
plt.xticks(rotation=90)
plt.title("Top 10 location that theft do happened in the city of chicago",size=25)
plt.show()

# %%
swlk=dfFinal.query("Location_Description =='SIDEWALK'")
swlk
# Out:
#                          Block        Primary_Type  \
# 10         031XX W WARREN BLVD           NARCOTICS
# 18           002XX N LOREL AVE           NARCOTICS
# 40            007XX W 103RD ST             BATTERY
# 42        077XX S PHILLIPS AVE             BATTERY
# 53         052XX W DIVISION ST           NARCOTICS
# ...                        ...                 ...
# 100002       044XX W FULTON ST           NARCOTICS
# 100038    015XX W ROOSEVELT RD           NARCOTICS
# 100046  002XX N KILPATRICK AVE   WEAPONS VIOLATION
# 100105     018XX W FARWELL AVE  DECEPTIVE PRACTICE
# 100106    019XX S ST LOUIS AVE           NARCOTICS
#
#                           Description Location_Description  Arrest  Domestic  \
# 10       MANU/DELIVER: HEROIN (WHITE)             SIDEWALK    True     False
# 18                        POSS: CRACK             SIDEWALK    True     False
# 40      AGGRAVATED: OTHER DANG WEAPON             SIDEWALK   False     False
# ...

# %% [markdown]
# # Dashboard by Dash

# %%
from jupyter_dash import JupyterDash
import dash
from dash import dcc
from dash import html
import dash_bootstrap_components as dbc
import plotly.express as px  
import plotly.graph_objects as go 
import pandas as pd

from dash.dependencies import Input, Output

# %%
data=pd.read_csv("Final Data.csv")
data["District"]=data["District"].astype(int)
data["District"]=data["District"].astype(object)

available_Crime=data["Primary_Type"].unique()
available_Location=data["Location_Description"].unique()
District=data["District"].unique()

# %%
# css style
st1={'color': '#fff',
  'background-color':'#6c757d',
  'border-color': '#28a745',"font-size":" 20px"}

st2={"font-size":"35px"}

st3={"font-size":"35px"}

custom_tab_selected ={
    "color": "black",
    "box-shadow": "1px 1px 0px white",
    'border-left': '1px solid lightgrey !important',
    'border-right': '1px solid lightgrey !important',
    'border-top': '3px solid #e36209 !important',
}

custom_tab ={
    'color':'#fff',
    'border-top-left-radius': '3px',
    'border-top-right-radius': '3px',
    'border-top': '3px',
    'align-items': 'center',
    'justify-content': "center",
     'font-family': "system-ui",'background-color': '#11aeef',
     'border': 'thin lightgrey solid', 
      'overflowX': 'scroll'}


custom_tabs= {
    " width": "100%",
    "border-top-left-radius": "1px",
    "background-color": "#f9f9f9",
    "padding": "0px 24px",
    "border-bottom": "1px solid #d6d6d6"
}
graph_style={'width':'50%','float':'right','display':'inline-block'}
graph_styleL={'width':'50%','float':'left','display':'inline-block'}
graph_style2={'width':'99%','display':'inline-block','padding': '0 80'}
year={'width': '38%', 'padding': '0px 20px 20px 20px'}




#init the app
app = JupyterDash(__name__,external_stylesheets=[dbc.themes.BOOTSTRAP,dbc.icons.BOOTSTRAP])
server = app.server






# build componebnts
header_comp=html.H1("CHICAGO CRIME CITY",style={"color":"#fff","text-align":"center","font-size":"60px"})
avail_crime=dcc.Dropdown(
                id='crime',options=[{"label":i,"value":i} for i in available_Crime],
                value='THEFT')
avail_Loc=dcc.Dropdown(id='Location', options=[{"label":i,"value":i} for i in available_Location],
                value='STREET')
avail_Dis=dcc.Dropdown(id="District",options=[{"label":i,"value":i} for i in District],
                value='17')
year1=dcc.Slider(
        id='crossfilter-year--slider',min=data['Year'].min(),
        max=data['Year'].max(), value=data['Year'].max(),marks={str(year): str(year) for year in data['Year'].unique()},
        step=None)
year2=dcc.Slider(
        id='crossfilter-Loc_year--slider',min=data['Year'].min(),
        max=data['Year'].max(), value=data['Year'].max(),marks={str(year): str(year) for year in data['Year'].unique()},
        step=None)
year3=dcc.Slider(
        id='crossfilter-Dis_year--slider',min=data['Year'].min(),
        max=data['Year'].max(), value=data['Year'].max(),marks={str(year): str(year) for year in data['Year'].unique()},
        step=None)

name="Top 2O location for this crime in the city of Chicago"

name1="Top 20 Primary Crime for this location in the city of chicago"
nameD="Top 2O Primary for this District  in the city of Chicago"



#design app layout
app.layout=html.Div([
            dbc.Row(header_comp),
            dbc.Row([
            dcc.Tabs([
                dcc.Tab([
                    html.Div([html.H2("Project Brief"),
                             html.Div([
                            html.P(""" Crime in Chicago has been worrisome to the chicago PD.
                            Reported Crimes have been tracked on a daily basis
                            since 2001 and have been provided in the project data file. 
                            The Chicago PD would like to drastically reduce the spate
                            of violent crimes reported in the city. Being effective involves
                            knowing crime pattern and where they are likely to occur.
                            It also involves equipping the Police Department appropriately. 
                            They have recruited you to conduct 
                            full data analytics and uncover insights from the data that can be
                            used to effectively prepere for and respond to crimes. """),
                            html.Br(),
                            html.P("They are interested in gleaning any insight that can help them determine"),
                            html.Li("What type of Crime to Prepare for?"),
                            html.Li("Where these Crimes are mostly to occur?"),
                            html.Li("What days of the week and periods to expect these crimes?"),
                            html.Br(),
                            html.P("This Period of Time "),
                            html.Li("Early Morning (4am-8am inclusive)"),
                            html.Li("Late Morning ( 9am-11am inclusive)"),
                            html.Li("Mid-day&Early Afternoon (12pm-2pm inclusive)"),
                            html.Li("Late Afternoon(3pm-4pm inclusive"),
                            html.Li("Evening (5pm-7pm inclusive)"),
                            html.Li("Early Night(8pm-11pm inclusive)"),
                            html.Li("late Night(12pm-3am inclusive)")
                            ],style=st2),]),]
                ,label="Project Brief",style=st1),
                dcc.Tab(label="Primary_Crime",
                        children=[
                            dbc.Row([
                                dbc.Row([
                                         html.Br(),
                                         dbc.Col([year1],style=year),
                                         html.Div([html.Label("Primary Crime Type")],style=custom_tab_selected),
                                        avail_crime],style=custom_tabs),
                                
                            dbc.Col([dcc.Graph(id="Crime-Location_bar")],style=graph_style2),
                                html.Br(),
                            dbc.Col([dcc.Graph(id="Crime-D_O_W_bar")],style=graph_styleL),
                            dbc.Col([dcc.Graph(id="Crime-Period_bar")],style=graph_style),
                            ])
                        ],style=st1 
                       ),
                dcc.Tab(label="Location_Description",
                       children=[
                            dbc.Row([
                                dbc.Row([html.Img(),
                                         html.Br(),
                                         dbc.Col([year2],style=year),
                                         html.Label("Location Description"),
                                        avail_Loc],custom_tab_selected),
                                
                            dbc.Col([dcc.Graph(id="Loc_Primary_bar")],style=graph_style2),
                                  html.Br(),
                            dbc.Col([dcc.Graph(id="Loc_D_O_W_bar")],style=graph_styleL),
                            dbc.Col([dcc.Graph(id="Loc_Period_bar")],style=graph_style),
                            ])
                        ],style=st1),
                dcc.Tab(label="District",
                       children=[
                            dbc.Row([
                                dbc.Row([dbc.CardImg(),
                                         html.Br(),
                                         dbc.Col([year3],style=year),
                                         html.Label("District"),
                                        avail_Dis],style=custom_tabs),
                                
                            dbc.Col([dcc.Graph(id="Dis-Primary bar")],style=graph_style2),
                                  html.Br(),
                            dbc.Col([dcc.Graph(id="Dis-Location bar")],style=graph_style2),
                                  html.Br(),
                            dbc.Col([dcc.Graph(id="Dis_D_O_W bar")],style=graph_styleL),
                            dbc.Col([dcc.Graph(id="Dis_Period bar")],style=graph_style),
                            ])
                        ],style=st1),
                dbc.Tab([
           html.Ul([
               html.H2("INSIGHTS",style={'textAlign': 'left',
                                        "color":"#e83e8c", "background-color": '#fff'}),
               html.H3("There are some insight for some crime that happened."),
               html.Br(),
               html.Li('There are 35 different crime reported to the Chicago PD in this of dataset,'),
               html.Li('There are 146 different crime location reported to the Chicago PD in this of dataset'),
               html.Li('There are 23 Distrit circuit reported to Chicago PD where these crimes occurs'),
               html.Li("""Most Theft happened on the streets,resdience place like apartment etc and stores.
               They"re mostly monetary values like money,clocks etc.Most Theft happened during the mid-day/Early
                Afternoon(12pm-3pm), Evening(5pm-7pm) and Early-Night(8pm-11pm). At or Around 12 pm mid-day,
                 there is a lot of theft. The rate of theft increase during the end of month."""),
               html.Li("""Most battery happened on the streets,resdience place like apartment etc and public places.
                Most Battery reported are simple like beating up. Most Battery happened during the Night and evening. 
                South region of the city has more battery Crime than Others."""),
               html.Li("""- Most Narcotics happened on the streets and side walk  especialy early at
               Night around 7pm to 11pm. It is mostly rampant in the region (West and North) of the City.
               Most Narcotics are hard drug like cannabils,cracks and heroin. There is no period/season 
               they don't take drug abd rate of theft increase as the end of month.
               """),
               html.Li("""
                Most Robbery happen on the street,sidewalk and public space like CTA Train , Gas Station.
                Most Robbery are without weapon like strongman.It occur mostly early Night and Evening."""),
               html.Li("""
               Most criminal_damage happen on the street,residence area and apartment.
               Criminal_damage are most on vechicle and property.It happens most at night and evening.
               The region where criminal_damage happen most is south and west of the city chicago."""),
               html.Br(),
               
           ]),
                            
           
            

       ], label='INSIGHT',style=st3
                )
            ])])
],style=custom_tab)



@app.callback(
               Output("Crime-Location_bar","figure"),
              [Input('crossfilter-year--slider','value'),
               Input('crime','value')] )

def update_chart(year_value,crime_value):
    dff=data[data['Year']<=year_value]
    crime=dff[dff["Primary_Type"]==crime_value]
    act_group=crime.groupby(by="Location_Description")["District"].count().sort_values(ascending=False).reset_index(name="counts")[:20]
    fig = go.Figure() # Canvass
    fig = px.bar(act_group, y='counts', x='Location_Description', text='counts', color='Location_Description')
    fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
    fig.update_layout(xaxis_tickangle=-45,template="plotly_dark",title=dict(text=name,
                                                                           font=dict(family="Sherif",
                                                                                    size=25,
                                                                                    color='red')))
    return fig



@app.callback(
               Output("Crime-D_O_W_bar","figure"),
              [Input('crossfilter-year--slider','value'),
               Input('crime','value')] )

def update_chart(year_value,crime_value):
    dff=data[data['Year']<=year_value]
    crime=dff[dff["Primary_Type"]==crime_value]
    act_group=crime.groupby(by="day")["District"].count().sort_values(ascending=False).reset_index(name="counts")[:20]
    fig = go.Figure() # Canvass
    fig = px.bar(act_group, y='counts', x='day', text='counts', color='day')
    fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
    fig.update_layout(xaxis_tickangle=-45 ,template="plotly_dark",
                      title=dict(text="Chart showing Day Of Week Of This Crime Happened",
                        font=dict(family="Sherif",
                     size=25,
                     color='red')))
    return fig



@app.callback(
               Output("Crime-Period_bar","figure"),
              [Input('crossfilter-year--slider','value'),
               Input('crime','value')] )


def update_chart(year_value,crime_value):
    dff=data[data['Year']<=year_value]
    crime=dff[dff["Primary_Type"]==crime_value]
    act_group=crime.groupby(by="Period_time")["District"].count().sort_values(ascending=False).reset_index(name="counts")[:20]
    fig = go.Figure() # Canvass
    fig = px.bar(act_group, y='counts', x='Period_time', text='counts', color='Period_time')
    fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
    fig.update_layout(xaxis_tickangle=-45,template="plotly_dark",
                     title=dict(text="Chart showing Period Of WhichThis Crime Happened",
                        font=dict(family="Sherif",
                     size=25,
                     color='red')))
    return fig
##### Location


@app.callback(
               Output("Loc_Primary_bar","figure"),
              [Input('crossfilter-Loc_year--slider','value'),
               Input('Location','value')] )

def update_chart(Loc_year,Location):
    dff=data[data["Year"]<=Loc_year]
    locD=dff[dff["Location_Description"]==Location]
    act_group=locD.groupby(by="Primary_Type")["District"].count().sort_values(ascending=False).reset_index(name="counts")[:20]
    fig = go.Figure() # Canvass
    fig = px.bar(act_group, y='counts', x='Primary_Type', text='counts', color='Primary_Type')
    fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
    fig.update_layout(xaxis_tickangle=-45,template="plotly_dark" ,title=dict(text=name1,
                                                                           font=dict(family="Sherif",
                                                                                    size=25,
                                                                                    color='red')))
    return fig





@app.callback(
               Output("Loc_D_O_W_bar","figure"),
              [Input('crossfilter-Loc_year--slider','value'),
               Input('Location','value')] )

def update_chart(Loc_year,Location):
    dff=data[data["Year"]<=Loc_year]
    locD=dff[dff["Location_Description"]==Location]
    act_group=locD.groupby(by="day")["District"].count().sort_values(ascending=False).reset_index(name="counts")[:20]
    fig = go.Figure() # Canvass
    fig = px.bar(act_group, y='counts', x='day', text='counts', color='day')
    fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
    fig.update_layout(xaxis_tickangle=-45,template="plotly_dark",
                     title=dict(text="Chart showing Day Of Week That Crime Happened In This Location",
                        font=dict(family="Sherif",
                     size=25,
                     color='red')))
    return fig





@app.callback(
               Output("Loc_Period_bar","figure"),
              [Input('crossfilter-Loc_year--slider','value'),
               Input('Location','value')] )

def update_chart(Loc_year,Location):
    dff=data[data["Year"]<=Loc_year]
    locD=dff[dff["Location_Description"]==Location]
    act_group=locD.groupby(by="Period_time")["District"].count().sort_values(ascending=False).reset_index(name="counts")[:20]
    fig = go.Figure() # Canvass
    fig = px.bar(act_group, y='counts', x='Period_time', text='counts', color='Period_time')
    fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
    fig.update_layout(xaxis_tickangle=-45,template="plotly_dark",
                     title=dict(text="Chart showing Period Crime Happened In This Location",
                        font=dict(family="Sherif",
                     size=25,
                     color='red')))
    return fig






######## Districts
@app.callback(
               Output("Dis-Primary bar","figure"),
              [Input('crossfilter-Dis_year--slider','value'),
               Input('District','value')] )


def update_chart(Dis_year,District):
    dff=data[data["Year"]<=Dis_year]
    locD=dff[dff["District"]==District]
    act_group=locD.groupby(by="Primary_Type")["Location_Description"].count().sort_values(ascending=False).reset_index(name="counts")[:20]
    fig = go.Figure() # Canvass
    fig = px.bar(act_group, y='counts', x='Primary_Type', text='counts', color='Primary_Type')
    fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
    fig.update_layout(xaxis_tickangle=-45,template="plotly_dark",
                      title=dict(text=nameD,
                        font=dict(family="Sherif",
                        size=25,
                        color='red')))
    return fig



@app.callback(
               Output("Dis-Location bar","figure"),
              [Input('crossfilter-Dis_year--slider','value'),
               Input('District','value')] )


def update_chart(Dis_year,District):
    dff=data[data["Year"]<=Dis_year]
    locD=dff[dff["District"]==District]
    act_group=locD.groupby(by="Location_Description")["Primary_Type"].count().sort_values(ascending=False).reset_index(name="counts")[:20]
    fig = go.Figure() # Canvass
    fig = px.bar(act_group, y='counts', x="Location_Description", text='counts', color="Location_Description")
    fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
    fig.update_layout(xaxis_tickangle=-45,template="plotly_dark")
    return fig




@app.callback(
               Output("Dis_D_O_W bar","figure"),
              [Input('crossfilter-Dis_year--slider','value'),
               Input('District','value')] )


def update_chart(Dis_year,District):
    dff=data[data["Year"]<=Dis_year]
    locD=dff[dff["District"]==District]
    act_group=locD.groupby(by="day")["Primary_Type"].count().sort_values(ascending=False).reset_index(name="counts")[:20]
    fig = go.Figure() # Canvass
    fig = px.bar(act_group, y='counts', x="day", text='counts', color="day")
    fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
    fig.update_layout(xaxis_tickangle=-45,template="plotly_dark",
                     title=dict(text="Chart showing Day Of Week Of This Crime Happened in this District",
                        font=dict(family="Sherif",
                     size=25,
                     color='red')))
    return fig





@app.callback(
               Output("Dis_Period bar","figure"),
              [Input('crossfilter-Dis_year--slider','value'),
               Input('District','value')] )


def update_chart(Dis_year,District):
    dff=data[data["Year"]<=Dis_year]
    locD=dff[dff["District"]==District]
    act_group=locD.groupby(by="Period_time")["Primary_Type"].count().sort_values(ascending=False).reset_index(name="counts")[:20]
    fig = go.Figure() # Canvass
    fig = px.bar(act_group, y='counts', x="Period_time", text='counts', color="Period_time")
    fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
    fig.update_layout(xaxis_tickangle=-45,template="plotly_dark",
                     title=dict(text="Chart showing Period Of This Crime Happened In This District",
                        font=dict(family="Sherif",
                     size=25,
                     color='red')))
    return fig

# %%
app.run_server(port="8080")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\Dell\Documents\Cohort work\Final Project\Chicago Dataset.ipynb Cell 120 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dell/Documents/Cohort%20work/Final%20Project/Chicago%20Dataset.ipynb#Y230sZmlsZQ%3D%3D?line=0'>1</a> app.run_server(port="8080")
#
# File ~\AppData\Roaming\Python\Python39\site-packages\jupyter_dash\jupyter_app.py:339, in JupyterDash.run_server(self, mode, width, height, inline_exceptions, **kwargs)
#     329         url = "http://{host}:{port}".format(
#     330             host=host, port=port, token=JupyterDash._token
#     331         )
#     332         raise OSError(
#     333             "Address '{url}' already in use.\n"
#     334             "    Try passing a different port to run_server.".format(
#     335                 url=url
#     336             )
# ...

# %%
app.run_server(mode='inline',debug=True, port='8037')
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8037/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\ProgramData\Anaconda3\lib\site-packages\plotly\express\_chart_types.py:368, in bar(
#     data_frame=               Period_time  counts
# 0  Mid-day/Ea...ernoon    2618
# 6            Early Morning    1954,
#     x='Period_time',
#     y='counts',
#     color='Period_time',
#     pattern_shape=None,
#     facet_row=None,
#     facet_col=None,
#     facet_col_wrap=0,
#     facet_row_spacing=None,
#     facet_col_spacing=None,
#     hover_name=None,
#     hover_data=None,
#     custom_data=None,
#     text='counts',
#     base=None,
#     error_x=None,
#     error_x_minus=None,
#     error_y=None,
#     error_y_minus=None,
# ...
